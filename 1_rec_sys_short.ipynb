# %% [markdown]
# # Recommendation System
#
# ## 1. Train/Test - 80%/25%
#
# ## 2. Cross Validation - 25%, 25%, 25%, 25%
#
# ## 3. Accuracy Metrics
# Accuracy metrics - Average error
#
# ### Mean absolute error metric (MAE)
# System rating - User rating = Error (difference)
# #### Root mean square error (RMSE) - Netflix
# Ингэснээр positive тоо гаргана.
#
# ## 4. Top-N Hit Rate
# Hits(user rated) / users = Hit Rate
#
# ### Average reciprocal hit rate (ARHR) - Netflix
#
# ### Cumulative hit rate (cHR)
#
# ### Rating hit rate (rHR)
#
# ## 5. Coverage
# Хамрах хүрээ
# Percentage of user, item pairs that can be predicted.
# Хэрэглэгчид санал болгох магадлалтай хэсэг буюу хувь.
#
# ## 6. Diversity
# Олон талт байдал
# Эсрэг recommendation. Цөөнхийг санал болгох.
# (1 - S)
# S = average similarity between recommendation pairs
#
# Which metric tells us whether we're recommending the same types of things all the time? Recommendation-үүдийн ижил төстэй байдлыг эсрэгээр нь авч хэт их ижил төстэй бус хамааралгүй item-уудыг олох боломжтой.
#
# ## 7. Novel
# Хэр нийтэд алдартай бүтээгдэхүүнийг санал болгож байгааг харуулах хэмжигдэхүүн.
# Итгэл
# Novelty is a measure of how popular the items are that you're recommending.
#
# ## 8. Churn
# Ижил recommendation байнга санал болгох бус top-N-ийг random байдлаар санал болгох.
# How often do the recommendations for a user change?
# In part, churn can measure how sensitive your recommender system is to new user behavior.
#
# ## 9. Responsiveness
# Шууд өөрчлөх үү эсвэл тодорхой хугацааны дараа өөрчлөгдөх үү? Үүний балансыг барих.
# How quickly does new user behavior influence your recommendations?
# You need to strike your own balance between responsiveness and simplicity.
#
# ## 10. A/B tests
# A/B test хийснээр аль metric хамгийн чухал вэ гэдгийг тодорхойлох боломжтой.
# Хамгийн чухал хэмжүүр.
#
# ## 11. Perceived quality
# Like, Dislike
# Хүлээн зөвшөөрөгдсөн чанар
# Хэрэглэгчид дуртай дургүйгээ сонгох боломж олгох.
